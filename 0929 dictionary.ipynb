# %%
dic = {"學校課表":["程式語言","瑜珈","網路設計","離散數學","資料庫理論","大數據分析導論"],"補習班課表":["線性代數","離散數學","作業系統","資料結構","演算法","計組"]}
kl = []
vl = []
for i in dic.keys():
    kl.append(i)
print("課表分類:",kl)

for i in dic.values():
    vl.append(i)
print("------------------------------------------------------------------------------------")
print("課程內容:",vl)

dic["學校課表"]=["程式語言","瑜珈","網路設計","離散數學","資料庫理論","大數據分析導論","電腦多媒體製作"]
print("------------------------------------------------------------------------------------")
print(dic)
# Out:
# 課表分類: ['學校課表', '補習班課表']
# ------------------------------------------------------------------------------------
# 課程內容: [['程式語言', '瑜珈', '網路設計', '離散數學', '資料庫理論', '大數據分析導論'], ['線性代數', '離散數學', '作業系統', '資料結構', '演算法', '計組']]
# ------------------------------------------------------------------------------------
# {'學校課表': ['程式語言', '瑜珈', '網路設計', '離散數學', '資料庫理論', '大數據分析導論', '電腦多媒體製作'], '補習班課表': ['線性代數', '離散數學', '作業系統', '資料結構', '演算法', '計組']}
