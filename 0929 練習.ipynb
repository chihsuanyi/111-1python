# %%
#題目一

a1 = {'第62條':'汽車駕駛人駕駛汽車肇事',
      '第12條':'汽車使用吊銷、註銷之牌照' }
a2 = {'第62條':2000,
      '第12條':5000}
paymentA = 0
for i in a2:
    paymentA += a2[i]

b1 = {'第16條':'裝置高音量喇叭或其他產生噪音器物',
      '第56條':'在禁止臨時停車處所停車',
      '第82條':'未經許可在道路擺設攤位',
      '第17條':'汽車不依限期參加定期檢驗或臨時檢驗'}
b2 = {'第16條':1200,
      '第56條':800,
      '第82條':1500,
      '第17條':900}
paymentB = 0
for i in b2:
    paymentB += b2[i]

c1 = {'第21條':'未領有駕駛執照駕駛小型車或機車'}
c2 = {'第21條':8000}
paymentC = 0
for i in c2:
    paymentC += c2[i]

A = {"name":"甲",
     "age":40,
     "觸犯條例":a1,  
     "罰鍰": a2}

B = {"name":"乙",
     "age":52,
     "觸犯條例":b1,  
     "罰鍰":b2}

C = {"name":"丙",
     "age":63,
     "觸犯條例":c1,  
     "罰鍰":c2}

while True:
    R = input("輸入數字: 1查看甲資料 2查看乙資料 3查看丙資料 4犯罪數排名 5累積罰金&罰鍰數排名 6結束程式" )
    if R=="1":
        print("Name:",A["name"],"\nAge:",A["age"],"\n共觸犯(條):",len(a1),"\n條例內容:",a1,"\n罰鍰總額:",paymentA,"\n詳細內容:",a2)
    elif R=="2":
        print("Name:",B["name"],"\nAge:",B["age"],"\n共觸犯(條):",len(b1),"\n條例內容:",b1,"\n罰鍰總額:",paymentB,"\n詳細內容:",b2)
    elif R=="3":
        print("Name:",C["name"],"\nAge:",C["age"],"\n共觸犯(條):",len(c1),"\n條例內容:",c1,"\n罰鍰總額:",paymentC,"\n詳細內容:",c2)
    elif R=="4":
        if len(a1)>=len(b2)>=len(c2):
            print("甲>=乙>=丙")
        if len(a1)>=len(c2)>=len(b2):
            print("甲>=丙>=乙")
        if len(b2)>=len(c2)>=len(a1):
            print("乙>=丙>=甲")
        if len(b2)>=len(a2)>=len(c1):
            print("乙>=甲>=丙")
        if len(c2)>=len(a1)>=len(b2):
            print("丙>=甲>=乙")
        if len(c2)>=len(b1)>=len(a2):
            print("丙>=乙>=甲")      
    elif R=="5":
        if paymentA>=paymentB>=paymentC:
            print("甲>=乙>=丙")
        if paymentA>=paymentC>=paymentB:
            print("甲>=丙>=乙")
        if paymentB>=len(c2)>=paymentA:
            print("乙>=丙>=甲")
        if paymentB>=paymentA>=paymentC:
            print("乙>=甲>=丙")
        if paymentC>=paymentA>=paymentB:
            print("丙>=甲>=乙")
        if paymentC>=paymentB>=paymentA:
            print("丙>=乙>=甲")
    elif R=="6":
        break
    else:
        print('輸入錯誤，請重新輸入')
        continue
# Out:
# 輸入數字: 1查看甲資料 2查看乙資料 3查看丙資料 4犯罪數排名 5累積罰金&罰鍰數排名 6結束程式1
# Name: 甲
# Age: 40
# 共觸犯(條): 2
# 條例內容: {'第62條': '汽車駕駛人駕駛汽車肇事', '第12條': '汽車使用吊銷、註銷之牌照'}
# 罰鍰總額: 7000
# 詳細內容: {'第62條': 2000, '第12條': 5000}
# 輸入數字: 1查看甲資料 2查看乙資料 3查看丙資料 4犯罪數排名 5累積罰金&罰鍰數排名 6結束程式2
# Name: 乙
# Age: 52
# 共觸犯(條): 4
# 條例內容: {'第16條': '裝置高音量喇叭或其他產生噪音器物', '第56條': '在禁止臨時停車處所停車', '第82條': '未經許可在道路擺設攤位', '第17條': '汽車不依限期參加定期檢驗或臨時檢驗'}
# 罰鍰總額: 4400
# 詳細內容: {'第16條': 1200, '第56條': 800, '第82條': 1500, '第17條': 900}
# 輸入數字: 1查看甲資料 2查看乙資料 3查看丙資料 4犯罪數排名 5累積罰金&罰鍰數排名 6結束程式3
# Name: 丙
# Age: 63
# 共觸犯(條): 1
# 條例內容: {'第21條': '未領有駕駛執照駕駛小型車或機車'}
# 罰鍰總額: 8000
# 詳細內容: {'第21條': 8000}
# 輸入數字: 1查看甲資料 2查看乙資料 3查看丙資料 4犯罪數排名 5累積罰金&罰鍰數排名 6結束程式4
# 乙>=甲>=丙
# 輸入數字: 1查看甲資料 2查看乙資料 3查看丙資料 4犯罪數排名 5累積罰金&罰鍰數排名 6結束程式5
# 丙>=甲>=乙
# 輸入數字: 1查看甲資料 2查看乙資料 3查看丙資料 4犯罪數排名 5累積罰金&罰鍰數排名 6結束程式7
# 輸入錯誤，請重新輸入
# 輸入數字: 1查看甲資料 2查看乙資料 3查看丙資料 4犯罪數排名 5累積罰金&罰鍰數排名 6結束程式6
